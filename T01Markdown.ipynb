# %% [markdown]
# Hola Me llamo Milca, me gusta jugar videojuegos, me encanta el volleyball, tengo 19 años y estudio Ingeniería financiera.
# En este caso la programación se utiliza al tema de la bolsa de valores, para poder predecir el movimiento de las acciones.

# %% [markdown]
# # Título

# %% [markdown]
# ## Subtítulo

# %% [markdown]
# **Uso de Negritas**

# %% [markdown]
# *Cúrsiva*

# %% [markdown]
# <p›Párrafo <p/>
# <p›Párrafo <p/>
# <p›Párrafo<p/>
# Párrafo

# %% [markdown]
# ![iteso%20-%20Editada.ico](attachment:iteso%20-%20Editada.ico)

# %% [markdown]
# 1.
# 2.
# 3.
# 4.

# %% [markdown]
# -
# -
# -
# -

# %% [markdown]
# $$ Z = \frac{y^3}{\sqrt{Y}} $$

# %% [markdown]
# $$ 2 $$
